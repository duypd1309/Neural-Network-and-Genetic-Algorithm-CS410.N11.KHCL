# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
x = [10, 20, 40, 80, 160]
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(16,16))

### OneMax
# MRPS
ax = axs[0][0]

# 1X
y1X = [26.8, 74, 201.6, 723.2, 3136]
y1X_std = [3.6, 11.207, 47.571, 185.6, 787.486]

# UX
yUX = [19.6, 33.2, 59.6, 96, 146.4]
yUX_std = [3.980, 6.765, 9.871, 15.179, 16.8]

ax.errorbar(x, y1X, yerr=y1X_std, uplims=True, lolims=True, label='1X')
ax.errorbar(x, yUX, yerr=yUX_std, uplims=True, lolims=True, label='UX')

ax.set_title('MRPS of OneMax')
ax.set_yscale('log')
ax.set_xlabel('Problem size')
ax.set_ylabel('MRPS')
ax.legend()


# num_evaluations
ax = axs[0][1]

# 1X
y1X = [216.02, 875.88, 3623.36, 19082.88, 122190.08]
y1X_std = [26.278, 126.998, 735.391, 4251.214, 27845.459]

# UX
yUX = [142.46, 347.2, 860.84, 1975.44, 4289.28]
yUX_std = [26.256, 68.972, 132.057, 303.722, 465.710]

ax.errorbar(x, y1X, yerr=y1X_std, uplims=True, lolims=True, label='1X')
ax.errorbar(x, yUX, yerr=yUX_std, uplims=True, lolims=True, label='UX')

ax.set_title('num_evaluations of OneMax')
ax.set_yscale('log')
ax.set_xlabel('Problem size')
ax.set_ylabel('num_evaluations')
ax.legend()

### Trap5
# MRPS
ax = axs[1][0]

# 1X
y1X = [124.8, 272, 915.2, 3046.4]
y1X_std = [15.677, 50.088, 219.94, 837.006]

# UX
yUX = [366.4, 3020.8]
yUX_std = [87.182, 740.19]

ax.errorbar([10, 20, 40, 80], y1X, yerr=y1X_std, uplims=True, lolims=True, label='1X')
ax.errorbar([10, 20], yUX, yerr=yUX_std, uplims=True, lolims=True, label='UX')

ax.set_title('MRPS of Trap5')
ax.set_yscale('log')
ax.set_xlabel('Problem size')
ax.set_ylabel('MRPS')
ax.legend()

# num_evaluations
ax = axs[1][1]

# 1X
y1X = [1083.28, 3443.04, 17094.4, 85767.68]
y1X_std = [123.657, 612.403, 3955.843, 21325.292]

# UX
yUX = [4143.36, 69608.96]
yUX_std = [993.345, 16960.978]

ax.errorbar([10, 20, 40, 80], y1X, yerr=y1X_std, uplims=True, lolims=True, label='1X')
ax.errorbar([10, 20], yUX, yerr=yUX_std, uplims=True, lolims=True, label='UX')

ax.set_title('num_evaluations of Trap5')
ax.set_yscale('log')
ax.set_xlabel('Problem size')
ax.set_ylabel('num_evaluations')
ax.legend()

plt.show()

fig.savefig('plot.png', dpi=fig.dpi)
